# %%
profile_null = spark.read.format("csv").option("header","true").option("InferSchema","true")\
    .load("/FileStore/tables/nulldata_profile.csv")
profile_null.printSchema()                                                                       #  Loading the Dataset
# Out:
# root
#  |-- customerNumber: string (nullable = true)
#  |-- dateOfBirth: string (nullable = true)
#  |-- citizenshipCode: string (nullable = true)
#  |-- currCountryCode: string (nullable = true)
#  |-- employmentStatus: string (nullable = true)
#  |-- incomeInThousands: string (nullable = true)
#  |-- marketSegment: string (nullable = true)
#  |-- maritalStatus: string (nullable = true)
#  |-- stateCode: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- accountOpeningDate: string (nullable = true)
#  |-- gender: string (nullable = true)

# %%
print("No. of rows :", profile_null.count())
print("No. of columns :" ,len(profile_null.columns))
# Out:
# No. of rows : 136
# No. of columns : 13

# %%
profile_null = profile_null.dropDuplicates()                                                    # Dropping the Duplicate values

# %%
print("No. of rows :", profile_null.count())
print("No. of columns :" ,len(profile_null.columns))
# Out:
# No. of rows : 136
# No. of columns : 13

# %%
profile_null = profile_null.withColumn("incomeInThousands", profile_null.incomeInThousands.substr(2,10))            # Trimming the '$' symbol from income field

# %%
from pyspark.sql.functions import regexp_replace,col
profile_null = profile_null.withColumn('accountOpeningDate', regexp_replace(col('accountOpeningDate'), "/", "-"))          # Replacing '/' with'-'

# %%
from pyspark.sql.functions import regexp_replace,col
profile_null = profile_null.withColumn('dateOfBirth', regexp_replace(col('dateOfBirth'), "/", "-"))                        # Replacing '/' with '-'

# %%
from pyspark.sql.types import DateType
from pyspark.sql.functions import *
profile_null = profile_null.withColumn("accountOpeningDate",
to_date(col("accountOpeningDate"),"MM-dd-yyyy"))                                # Converting the Datatype

# %%
from pyspark.sql.types import DateType
from pyspark.sql.functions import *
profile_null = profile_null.withColumn("dateOfBirth",                                     # Converting the Datatype
to_date(col("dateOfBirth"),"dd-MM-yyyy"))

# %%
from pyspark.sql.types import FloatType
profile_null = profile_null.withColumn("incomeInThousands",
profile_null["incomeInThousands"].cast(FloatType()))                                            # Converting the Datatype

# %%
profile_null.printSchema()
# Out:
# root
#  |-- customerNumber: string (nullable = true)
#  |-- dateOfBirth: date (nullable = true)
#  |-- citizenshipCode: string (nullable = true)
#  |-- currCountryCode: string (nullable = true)
#  |-- employmentStatus: string (nullable = true)
#  |-- incomeInThousands: float (nullable = true)
#  |-- marketSegment: string (nullable = true)
#  |-- maritalStatus: string (nullable = true)
#  |-- stateCode: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- accountOpeningDate: date (nullable = true)
#  |-- gender: string (nullable = true)

# %%
profile_null.describe(['customerNumber','dateOfBirth','citizenshipCode','currCountryCode','employmentStatus']).show()
# Out:
# +-------+--------------------+---------------+---------------+----------------+
# |summary|      customerNumber|citizenshipCode|currCountryCode|employmentStatus|
# +-------+--------------------+---------------+---------------+----------------+
# |  count|                 136|            136|            136|             136|
# |   mean|                null|           null|           null|            null|
# | stddev|                null|           null|           null|            null|
# |    min|022d886f-0586-403...|             US|            USD|        employee|
# |    max|ffbb11ff-ca7f-42a...|           null|           null|          worker|
# +-------+--------------------+---------------+---------------+----------------+

# %%
profile_null.describe(['incomeInThousands','marketSegment','maritalStatus','stateCode']).show()
# Out:
# +-------+------------------+-------------+-------------+---------+
# |summary| incomeInThousands|marketSegment|maritalStatus|stateCode|
# +-------+------------------+-------------+-------------+---------+
# |  count|                90|          136|          136|      136|
# |   mean|253763.04461805554|         null|         null|     null|
# | stddev| 91378.76404586887|         null|         null|     null|
# |    min|         101653.52|          HNI|     Divorced|       AL|
# |    max|         396699.97|     standard|      Widowed|       WV|
# +-------+------------------+-------------+-------------+---------+

# %%
profile_null.describe(['city','country','accountOpeningDate','gender']).show()
# Out:
# +-------+------------+-------------+------+
# |summary|        city|      country|gender|
# +-------+------------+-------------+------+
# |  count|         136|          136|   136|
# |   mean|        null|         null|  null|
# | stddev|        null|         null|  null|
# |    min|      Albany|United States|Female|
# |    max|Winter Haven|United States|  Male|
# +-------+------------+-------------+------+

# %%
from pyspark.sql.functions import regexp_replace,col
profile_null = profile_null.withColumn('customerNumber', regexp_replace(col('customerNumber'), "[a-zA-Z]",""))

# %%
from pyspark.sql.functions import regexp_replace,col
profile_null = profile_null.withColumn('customerNumber', regexp_replace(col('customerNumber'), "-",""))

# %%
from pyspark.sql.functions import regexp_replace,col
profile_null = profile_null.withColumn('customerNumber', regexp_replace(col('customerNumber'), " ",""))

# %%
display(profile_null)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customerNumber</th><th>dateOfBirth</th><th>citizenshipCode</th><th>currCountryCode</th><th>employmentStatus</th><th>incomeInThousands</th><th>marketSegment</th><th>maritalStatus</th><th>stateCode</th><th>city</th><th>country</th><th>accountOpeningDate</th><th>gender</th></tr></thead><tbody><tr><td>2352814458345149377</td><td>1999-10-06</td><td>US</td><td>USD</td><td>null</td><td>101835.47</td><td>HNI</td><td>Widowed</td><td>KY</td><td>Lexington</td><td>United States</td><td>2021-04-11</td><td>Male</td></tr><tr><td>309706948685290127346</td><td>1998-03-06</td><td>US</td><td>USD</td><td>null</td><td>338895.75</td><td>HNI</td><td>Widowed</td><td>NY</td><td>Albany</td><td>United States</td><td>2021-09-27</td><td>Male</td></tr><tr><td>86190497861156781</td><td>2002-10-30</td><td>US</td><td>USD</td><td>employee</td><td>172196.56</td><td>null</td><td>Single</td><td>FL</td><td>Jacksonville</td><td>United States</td><td>2021-04-22</td><td>Male</td></tr><tr><td>796832854454688522688547</td><td>1995-09-11</td><td>US</td><td>USD</td><td>null</td><td>285960.75</td><td>standard</td><td>Married</td><td>PA</td><td>Harrisburg</td><td>United States</td><td>2021-11-23</td><td>Female</td></tr><tr><td>0688640575049843</td><td>1991-02-28</td><td>US</td><td>USD</td><td>null</td><td>183282.28</td><td>standard</td><td>Divorced</td><td>IN</td><td>South Bend</td><td>United States</td><td>2020-12-28</td><td>Male</td></tr><tr><td>8258308942670717969240</td><td>1992-11-08</td><td>US</td><td>USD</td><td>worker</td><td>null</td><td>basic</td><td>Separated</td><td>NY</td><td>Buffalo</td><td>United States</td><td>2021-10-20</td><td>Male</td></tr><tr><td>7441294141936023538749</td><td>2001-11-02</td><td>US</td><td>USD</td><td>worker</td><td>null</td><td>basic</td><td>Married</td><td>NC</td><td>Charlotte</td><td>United States</td><td>2021-02-22</td><td>Male</td></tr><tr><td>2087479002638208</td><td>1995-12-17</td><td>US</td><td>USD</td><td>worker</td><td>null</td><td>standard</td><td>Single</td><td>NY</td><td>New York City</td><td>United States</td><td>2021-11-22</td><td>Male</td></tr><tr><td>0853814448983605</td><td>2001-07-19</td><td>US</td><td>USD</td><td>null</td><td>null</td><td>HNI</td><td>Single</td><td>LA</td><td>Baton Rouge</td><td>United States</td><td>2021-01-25</td><td>Male</td></tr><tr><td>04951534994940796751</td><td>1992-06-14</td><td>US</td><td>USD</td><td>employee</td><td>null</td><td>HNI</td><td>Separated</td><td>MO</td><td>Kansas City</td><td>United States</td><td>2021-02-05</td><td>Female</td></tr><tr><td>472135246024753489</td><td>1998-01-03</td><td>US</td><td>USD</td><td>employee</td><td>null</td><td>HNI</td><td>Widowed</td><td>SC</td><td>Columbia</td><td>United States</td><td>2021-08-09</td><td>Male</td></tr><tr><td>90096944088534527808815</td><td>1991-05-12</td><td>US</td><td>USD</td><td>worker</td><td>null</td><td>basic</td><td>Divorced</td><td>FL</td><td>Fort Lauderdale</td><td>United States</td><td>2021-03-10</td><td>Male</td></tr><tr><td>55129544930440583110769756</td><td>1998-10-30</td><td>US</td><td>USD</td><td>employee</td><td>null</td><td>standard</td><td>Married</td><td>FL</td><td>Tampa</td><td>United States</td><td>2021-04-14</td><td>Male</td></tr><tr><td>1259485449184887115</td><td>2000-09-10</td><td>US</td><td>USD</td><td>null</td><td>266527.53</td><td>HNI</td><td>Separated</td><td>TX</td><td>Austin</td><td>United States</td><td>2021-11-11</td><td>Male</td></tr><tr><td>3100188354489428247138</td><td>1997-02-15</td><td>null</td><td>null</td><td>self-employed</td><td>278301.62</td><td>HNI</td><td>Single</td><td>FL</td><td>Panama City</td><td>United States</td><td>2021-04-17</td><td>Male</td></tr><tr><td>6628466943077559529762</td><td>1994-09-17</td><td>US</td><td>USD</td><td>worker</td><td>null</td><td>HNI</td><td>Separated</td><td>TX</td><td>Houston</td><td>United States</td><td>2021-10-18</td><td>Male</td></tr ...

# %%
profile_null.printSchema()
# Out:
# root
#  |-- customerNumber: string (nullable = true)
#  |-- dateOfBirth: date (nullable = true)
#  |-- citizenshipCode: string (nullable = true)
#  |-- currCountryCode: string (nullable = true)
#  |-- employmentStatus: string (nullable = true)
#  |-- incomeInThousands: float (nullable = true)
#  |-- marketSegment: string (nullable = true)
#  |-- maritalStatus: string (nullable = true)
#  |-- stateCode: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- accountOpeningDate: date (nullable = true)
#  |-- gender: string (nullable = true)

# %%
profile_null.createOrReplaceTempView("profile_null")

# %%
# %sql
SELECT employmentStatus,count(*) as Count FROM profile_null GROUP BY employmentStatus ORDER  BY COUNT(*) DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employmentStatus</th><th>Count</th></tr></thead><tbody><tr><td>null</td><td>59</td></tr><tr><td>worker</td><td>27</td></tr><tr><td>employee</td><td>26</td></tr><tr><td>self-employed</td><td>24</td></tr></tbody></table></div>

# %%
# %sql
SELECT marketSegment,count(*) as Count FROM profile_null GROUP BY marketSegment ORDER  BY COUNT(*) DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>marketSegment</th><th>Count</th></tr></thead><tbody><tr><td>standard</td><td>47</td></tr><tr><td>HNI</td><td>43</td></tr><tr><td>basic</td><td>34</td></tr><tr><td>null</td><td>12</td></tr></tbody></table></div>

# %%
# %sql
SELECT city,count(*) as Count FROM profile_null GROUP BY city ORDER  BY COUNT(*) DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>Count</th></tr></thead><tbody><tr><td>Sacramento</td><td>4</td></tr><tr><td>Washington</td><td>4</td></tr><tr><td>Charleston</td><td>3</td></tr><tr><td>Oklahoma City</td><td>3</td></tr><tr><td>Houston</td><td>3</td></tr><tr><td>Detroit</td><td>2</td></tr><tr><td>Baton Rouge</td><td>2</td></tr><tr><td>South Bend</td><td>2</td></tr><tr><td>Sarasota</td><td>2</td></tr><tr><td>Saint Petersburg</td><td>2</td></tr><tr><td>Trenton</td><td>2</td></tr><tr><td>Mobile</td><td>2</td></tr><tr><td>Albany</td><td>2</td></tr><tr><td>Tulsa</td><td>2</td></tr><tr><td>Buffalo</td><td>2</td></tr><tr><td>Knoxville</td><td>2</td></tr><tr><td>Torrance</td><td>2</td></tr><tr><td>Evansville</td><td>2</td></tr><tr><td>Seminole</td><td>2</td></tr><tr><td>Miami</td><td>2</td></tr><tr><td>Columbia</td><td>2</td></tr><tr><td>Huntington</td><td>2</td></tr><tr><td>Tampa</td><td>2</td></tr><tr><td>Charlotte</td><td>2</td></tr><tr><td>Alexandria</td><td>2</td></tr><tr><td>Newark</td><td>2</td></tr><tr><td>Arlington</td><td>2</td></tr><tr><td>Springfield</td><td>2</td></tr><tr><td>San Antonio</td><td>2</td></tr><tr><td>Los Angeles</td><td>2</td></tr><tr><td>Brooklyn</td><td>2</td></tr><tr><td>Stamford</td><td>2</td></tr><tr><td>Wichita</td><td>2</td></tr><tr><td>Escondido</td><td>2</td></tr><tr><td>Kansas City</td><td>2</td></tr><tr><td>Harrisburg</td><td>1</td></tr><tr><td>Sterling</td><td>1</td></tr><tr><td>Tallahassee</td><td>1</td></tr><tr><td>Omaha</td><td>1</td></tr><tr><td>Dayton</td><td>1</td></tr><tr><td>Boise</td><td>1</td></tr><tr><td>Austin</td><td>1</td></tr><tr><td>Cedar Rapids</td><td>1</td></tr><tr><td>Bakersfield</td><td>1</td></tr><tr><td>Fullerton</td><td>1</td></tr><tr><td>San Diego</td><td>1</td></tr><tr><td>Birmingham</td><td>1</td></tr><tr><td>Independence</td><td>1</td></tr><tr><td>El Paso</td><td>1</td></tr><tr><td>Warren</td><td>1</td></tr><tr><td>Longview</td><td>1</td></tr><tr><td>Salem</td><td>1</td></tr><tr><td>Lexington</td><td>1</td></tr><tr><td>Norfolk</td><td>1</td></tr><tr><td>Saint Louis</td><td>1</td></tr><tr><td>Manassas</td><td>1</td></tr><tr><td>San Francisco</td><td>1</td></tr><tr><td>Montgomery</td><td>1</td></tr><tr><td>Garden Grove</td><td>1</td></tr><tr><td>Mc Keesport</td><td>1</td></tr><tr><td>Memphis</td><td>1</td></tr><tr><td>Pasadena</td><td>1</td></tr><tr><td>Chicago</td><td>1</td></tr><tr><td>Fort Lauderdale</td><td>1</td></tr><tr><td>Corpus Christi</td><td>1</td></tr><tr><td>Waco</td><td>1</td></tr><tr><td>New Orleans</td><td>1</td></tr><tr><td>Las Vegas</td><td>1</td></tr><tr><td>Greenville</td><td>1</td></tr><tr><td>Huntsville</td><td>1</td></tr><tr><td>Muskegon</td><td>1</td></tr><tr><td>Colorado Springs</td><td>1</td></tr><tr><td>Roanoke</td><td>1</td></tr><tr><td>Tucson</td><td>1</td></tr><tr><td>Indianapolis</td><td>1</td></tr><tr><td>Santa Barbara</td><td>1</td></tr><tr><td>Panama City</td><td>1</td></tr><tr><td>Orlando</td><td>1</td></tr><tr><td>Portland</td><td>1</td></tr><tr><td>Hayward</td><td>1</td></tr><tr><td>Pittsburgh</td><td>1</td></tr><tr><td>Winter Haven</td><td>1</td></tr><tr><td>Amarillo</td><td>1</td></tr><tr><td>Jackson</td><td>1</td></tr><tr><td>Honolulu</td><td>1</td></tr><tr><td>Durham</td><td>1</td></tr><tr><td>Odessa</td><td>1</td></tr><tr><td>New York City</td><td>1</td></tr><tr><td>Duluth</td><td>1</td></tr><tr><td>Minneapolis</td><td>1</td></tr><tr><td>Jacksonville</td><td>1</td></tr><tr><td>Syracuse</td><td>1</td></tr><tr><td>Fort Myers</td><td>1</td></tr><tr><td>Denver</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
SELECT gender,count(*) as Count FROM profile_null GROUP BY gender ORDER  BY COUNT(*) DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gender</th><th>Count</th></tr></thead><tbody><tr><td>Male</td><td>108</td></tr><tr><td>Female</td><td>28</td></tr></tbody></table></div>

# %%
# %sql
select round(avg(ifnull(incomeInThousands,0)),2) as average_Income from profile_null
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>average_Income</th></tr></thead><tbody><tr><td>167931.43</td></tr></tbody></table></div>

# %%
# %sql
select max(incomeInThousands) from profile_null
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>max(incomeInThousands)</th></tr></thead><tbody><tr><td>396699.97</td></tr></tbody></table></div>
